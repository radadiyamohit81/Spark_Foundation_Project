# %%
# Importing all libraries required in this notebook
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt  
# %matplotlib inline

# %%
# Reading data from remote link
train_df = pd.read_csv("data/SampleSuperstore.csv")
print("Data imported successfully")

train_df.head(5)
# Out:
# Data imported successfully
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# ...

# %%
train_df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %%
# Average number of homeless families in Mountain Region.
train_df.loc[train_df['Ship Mode'] == 'Second Class'].mean()
# Out:
# Postal Code    55626.009254
# Sales            236.089239
# Quantity           3.816452
# Discount           0.138895
# Profit            29.535545
# dtype: float64

# %%
# Average number of homeless families in Mountain Region.
train_df.loc[train_df['Ship Mode'] == 'Standard Class'].mean()
# Out:
# Postal Code    54944.447051
# Sales            227.583067
# Quantity           3.819873
# Discount           0.160023
# Profit            27.494770
# dtype: float64

# %%
# Average number of homeless families in Mountain Region.
train_df.loc[train_df['Ship Mode'] == 'First Class'].mean()
# Out:
# Postal Code    54765.611834
# Sales            228.497024
# Quantity           3.701560
# Discount           0.164610
# Profit            31.839948
# dtype: float64

# %%
# Average number of homeless families in Mountain Region.
train_df.loc[train_df['Ship Mode'] == 'Same Day'].mean()
# Out:
# Postal Code    57536.082873
# Sales            236.396179
# Quantity           3.609576
# Discount           0.152394
# Profit            29.266591
# dtype: float64

# %%
# Our dataset doesn't contains NaN/Empty value so we can proceed further.
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 702.8+ KB

# %%
train_df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
train_df.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8);

# %% [markdown]
# Features such as `Postal Code`,`Sales`,`Quantity`,`Discount`,`Profit`,... seems to share a similar distribution Lets see if we can find new clues later.

# %%
# With the help of bar graph, depict which Mode has maximum profit and also depicts of more weak area.
plt.figure(figsize=(18, 8))
plt.bar(train_df["Ship Mode"], train_df["Profit"])
plt.show()

# %%
import seaborn as sns
sns.pairplot(train_df)

# %% [markdown]
# From Bar Graph now we can understand that the more negative profit is the `second class` so if we more focus on second class then obviously it will helping to increase income of our business.
